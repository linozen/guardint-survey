# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
df = pd.read_csv('./data/civsoc.csv', sep=',')

unwanted = ['Consentform.', 'seed.', 'submitdate.', 'id.']

for startstring in unwanted:
    unwanted_column = df.columns[df.columns.str.startswith(startstring)]
    df.drop(unwanted_column, axis=1, inplace=True)

df
# Out:
#     lastpage. Last page startlanguage. Start language  \
# 0                   NaN                            en
# 1                  23.0                            en
# 2                   1.0                            en
# 3                   1.0                            en
# 4                  19.0                            en
# 5                  23.0                            en
# 6                  23.0                            en
# 7                  23.0                            en
# 8                   3.0                            en
# 9                  23.0                            en
# 10                  2.0                            en
# 11                 23.0                            en
# 12                  0.0                            en
# 13                  1.0                            en
# 14                 23.0                            en
# 15                  5.0                            en
# 16                 11.0                            en
# 17                  1.0                            en
# 18                 23.0                            en
# 19                 23.0                            en
#
#    CShr1. What is your employment status?   \
# 0                                      NaN
# 1                 Part-time, less than 50%
# 2            Full-Time (40 hours per week)
# 3            Full-Time (40 hours per week)
# 4            Full-Time (40 hours per week)
# 5            Full-Time (40 hours per week)
# 6                                Freelance
# 7            Full-Time (40 hours per week)
# 8            Full-Time (40 hours per week)
# 9            Full-Time (40 hours per week)
# 10           Full-Time (40 hours per week)
# 11           Full-Time (40 hours per week)
# 12                                     NaN
# 13           Full-Time (40 hours per week)
# 14           Full-Time (40 hours per week)
# 15                  Part-time, 50% or more
# 16           Full-Time (40 hours per week)
# 17           Full-Time (40 hours per week)
# 18           Full-Time (40 hours per week)
# 19                               Freelance
#
#     CShr1other. If you selected ‘other’, please specify:  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#     CShr2. How many days per month do you work on surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1                                                4.00
# 2                                                 NaN
# 3                                                 NaN
# 4                                                1.00
# 5                                                4.00
# 6                                                0.00
# 7                                                3.00
# 8                                                2.00
# 9                                                1.00
# 10                                               0.25
# 11                                               2.00
# 12                                                NaN
# 13                                                NaN
# 14                                               2.00
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                               2.00
# 19                                               5.00
#
#    CSexpertise1. How many years have you spent working on surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1                                                  20
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   9
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  12
# 8                                                  12
# 9                                                  10
# 10                                                NaN
# 11                                                  5
# 12                                                NaN
# 13                                                NaN
# 14                                                 <1
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                  5
# 19                                                 20
#
#    CSexpertise2. How do you assess your level of expertise concerning the legal aspects of surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Advanced knowledge (I only require external ad...
# 5   Advanced knowledge (I only require external ad...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Expert knowledge (I rarely require external ad...
# 9   Advanced knowledge (I only require external ad...
# 10                                                NaN
# 11  Advanced knowledge (I only require external ad...
# 12                                                NaN
# 13                                                NaN
# 14  Basic knowledge (I require external advice in ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Some knowledge (I require external advice from...
# 19  Some knowledge (I require external advice from...
#
#    CSexpertise3. How do you assess your level of expertise concerning the political aspects of surveillance by intelligence agencies?   \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Some knowledge (I require external advice from...
# 5   Advanced knowledge (I only require external ad...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Advanced knowledge (I only require external ad...
# 9   Advanced knowledge (I only require external ad...
# 10                                                NaN
# 11  Some knowledge (I require external advice from...
# 12                                                NaN
# 13                                                NaN
# 14  Some knowledge (I require external advice from...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Advanced knowledge (I only require external ad...
# 19  Some knowledge (I require external advice from...
#
#    CSexpertise4. How do you assess your level of expertise concerning the technical aspects of surveillance by intelligence agencies?   \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Some knowledge (I require external advice from...
# 5   Some knowledge (I require external advice from...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Some knowledge (I require external advice from...
# 9   Some knowledge (I require external advice from...
# 10                                                NaN
# 11  Some knowledge (I require external advice from...
# 12                                                NaN
# 13                                                NaN
# 14    No knowledge (I always require external advice)
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Some knowledge (I require external advice from...
# 19  Some knowledge (I require external advice from...
#
#    CSfinance1. How do you assess the financial resources that have been available for your work on intelligence over the past 5 years?  \
# 0                                                 NaN
# 1   There was very little funding (It is exception...
# 2                                                 NaN
# 3                                                 NaN
# 4   There was sufficient funding (We have in most ...
# 5   There was very little funding (It is exception...
# 6   There was very little funding (It is exception...
# 7   There was very little funding (It is exception...
# 8                                                 NaN
# 9   There was sufficient funding (We have in most ...
# 10                                                NaN
# 11  There was very little funding (It is exception...
# 12                                                NaN
# 13                                                NaN
# 14  There was some funding (From time to time our ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  There was some funding (From time to time our ...
# 19  There was some funding (From time to time our ...
#
#    CSfinance2[SQ01]. How important are the following funding categories for your organisation's work on intelligence-related issues? [Private foundations]  \
# 0                                                 NaN
# 1                                           Important
# 2                                                 NaN
# 3                                                 NaN
# 4                                           Important
# 5                                           Important
# 6                                      Very important
# 7                                      Very important
# 8                                                 NaN
# 9                                      Very important
# 10                                                NaN
# 11                                     Very important
# 12                                                NaN
# 13                                                NaN
# 14                                 Slightly important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                          Important
# 19                                     Very important
#
#    CSfinance2[SQ02]. How important are the following funding categories for your organisation's work on intelligence-related issues? [Donations]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                           Important
# 5                                Not important at all
# 6                                      Very important
# 7                                Not important at all
# 8                                                 NaN
# 9                                Not important at all
# 10                                                NaN
# 11                                     Very important
# 12                                                NaN
# 13                                                NaN
# 14                                          Important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                 Slightly important
# 19                                 Slightly important
#
#    CSfinance2[SQ03]. How important are the following funding categories for your organisation's work on intelligence-related issues? [National public funds (including public foundations)]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                Not important at all
# 5                                  Slightly important
# 6                                Not important at all
# 7                                      Very important
# 8                                                 NaN
# 9                                Not important at all
# 10                                                NaN
# 11                               Not important at all
# 12                                                NaN
# 13                                                NaN
# 14                                 Somewhat important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                          Important
# 19                                          Important
#
#    CSfinance2[SQ04]. How important are the following funding categories for your organisation's work on intelligence-related issues? [Corporate sponsorship]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                Not important at all
# 5                                Not important at all
# 6                                  Somewhat important
# 7                                           Important
# 8                                                 NaN
# 9                                Not important at all
# 10                                                NaN
# 11                               Not important at all
# 12                                                NaN
# 13                                                NaN
# 14                                 Slightly important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                               Not important at all
# 19                                 Slightly important
#
#    CSfinance2[SQ05]. How important are the following funding categories for your organisation's work on intelligence-related issues? [International public funds (such as EU funds)]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                  Slightly important
# 5                                           Important
# 6                                Not important at all
# 7                                      Very important
# 8                                                 NaN
# 9                                Not important at all
# 10                                                NaN
# 11                               Not important at all
# 12                                                NaN
# 13                                                NaN
# 14                                          Important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                          Important
# 19                                 Slightly important
#
#    CSfinance2[SQ06]. How important are the following funding categories for your organisation's work on intelligence-related issues? [Other]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                Not important at all
# 7                                        I don't know
# 8                                                 NaN
# 9                                Not important at all
# 10                                                NaN
# 11                                       I don't know
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                       I don't know
#
#     CSfinance2other. If you selected ‘other’, please specify:  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    CSfinance3. Looking at the past year, which source of funding was most important in enabling you to work on intelligence-related issues?  \
# 0                                                 NaN
# 1                                        foundations.
# 2                                                 NaN
# 3                                                 NaN
# 4                              trusts and foundations
# 5   I managed to do intelligence-related work in t...
# 6   Have only obtained funding to work on cybersec...
# 7                                 Private foundations
# 8                                                 NaN
# 9                        Core funding from foundation
# 10                                                NaN
# 11                                Private Foundations
# 12                                                NaN
# 13                                                NaN
# 14                          Donations by governments
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                             Trusts and foundations
# 19                                  Private endowment
#
#    CSfinance4. What effect did your work on surveillance by intelligence agencies have for your organisation’s fundraising over the past 5 years?  \
# 0                                                 NaN
# 1                   Rather beneficial for fundraising
# 2                                                 NaN
# 3                                                 NaN
# 4                            No effect on fundraising
# 5                                        I don't know
# 6                  Clearly beneficial for fundraising
# 7                                        I don't know
# 8                                                 NaN
# 9                            No effect on fundraising
# 10                                                NaN
# 11                           No effect on fundraising
# 12                                                NaN
# 13                                                NaN
# 14                  Rather beneficial for fundraising
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                  Rather beneficial for fundraising
# 19                Rather constraining for fundraising
#
#    CSfoi1. Have you requested information under the national Freedom of Information Law when you worked on intelligence-related issues over the past 5 years?  \
# 0                                                 NaN
# 1                                                  No
# 2                                                 NaN
# 3                                                 NaN
# ...
# 17                                                NaN
# 18                                                NaN
# 19                                      Chatham House
#
#    CSsnowball[SQ03]. Thank you very much for your participation. It means a lot to us. Thanks to you and other voluntary participants we can advance the knowledge base on intelligence oversight and democratic control of surveillance in the digital age. If you like, please name up to three other experts or organisations that work on intelligence-related issues that you think could fill out this survey in order to provide us with an even better picture of civic intelligence oversight. (Please do not include contact information.) [Person or organisation 3]  \
# 0                                                 NaN
# 1                               Hermes Centre (Italy)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                   Open Rights Group
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                              Sir Bernard Silverman
#
#    CSEmail. If you want to hear about the results of this survey, please enter your email address here:
# 0                                                 NaN
# 1                                yasha@statewatch.org
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                  douwe@korff.co.uk
# 6                           javier@ruizmacpherson.org
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                     gph@herdale.uk

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
df = pd.read_csv('./data/civsoc.csv', sep=',')

df
# Out:
#     id. Response ID submitdate. Date submitted  lastpage. Last page  \
# 0                 6                        NaN                  NaN
# 1                 7        1980-01-01 00:00:00                 23.0
# 2                 8                        NaN                  1.0
# 3                 9                        NaN                  1.0
# 4                10                        NaN                 19.0
# 5                11        1980-01-01 00:00:00                 23.0
# 6                12        1980-01-01 00:00:00                 23.0
# 7                13        1980-01-01 00:00:00                 23.0
# 8                14                        NaN                  3.0
# 9                15        1980-01-01 00:00:00                 23.0
# 10               16                        NaN                  2.0
# 11               17        1980-01-01 00:00:00                 23.0
# 12               18                        NaN                  0.0
# 13               19                        NaN                  1.0
# 14               20        1980-01-01 00:00:00                 23.0
# 15               21                        NaN                  5.0
# 16               22                        NaN                 11.0
# 17               23                        NaN                  1.0
# 18               24        1980-01-01 00:00:00                 23.0
# 19               25        1980-01-01 00:00:00                 23.0
#
#    startlanguage. Start language  seed. Seed  \
# 0                             en  1786694227
# 1                             en  1842419691
# 2                             en   804636155
# 3                             en  1912324077
# 4                             en  2019272273
# 5                             en  1654743707
# 6                             en   543557303
# 7                             en   611140792
# 8                             en  1517812191
# 9                             en  2140491137
# 10                            en  1492796501
# 11                            en   231774669
# 12                            en   973757929
# 13                            en   690038735
# 14                            en   577239729
# 15                            en   911058481
# 16                            en  1320967380
# 17                            en   878766053
# 18                            en  1486813468
# 19                            en  1697284011
#
#    Consentform. RightsYou have the right to information about the data we hold on you and the purpose for which the data is stored. You have the right to rectify and erase any data that is stored without valid grounds. You have a right to data portability. If the personally identifiable data is processed based on legitimate interests, you have the right to lodge an objection. You can withdraw your consent at any time with reference to future processing, for instance by writing an Email to datenschutz@wzb.eu. Data processing up to the objection remains lawful.  Further you have the right to complain to a data protection authority.If you feel you have not been treated according to the descriptions in this form, or that your rights as a participant in research have not been honoured during the course of this project, or you have any questions, concerns, or complaints that you wish to address to someone other than the investigators, you may contact our data protection officer datenschutz@wzb.eu.Electronic ConsentBy clicking the button below, you agree with the following:- You have read the above information.- You voluntarily participate in this survey.  \
# 0                                                 NaN
# 1                                             I agree
# 2                                             I agree
# 3                                             I agree
# 4                                             I agree
# 5                                             I agree
# 6                                             I agree
# 7                                             I agree
# 8                                             I agree
# 9                                             I agree
# 10                                            I agree
# 11                                            I agree
# 12                                                NaN
# 13                                            I agree
# 14                                            I agree
# 15                                            I agree
# 16                                            I agree
# 17                                            I agree
# 18                                            I agree
# 19                                            I agree
#
#    CShr1. What is your employment status?   \
# 0                                      NaN
# 1                 Part-time, less than 50%
# 2            Full-Time (40 hours per week)
# 3            Full-Time (40 hours per week)
# 4            Full-Time (40 hours per week)
# 5            Full-Time (40 hours per week)
# 6                                Freelance
# 7            Full-Time (40 hours per week)
# 8            Full-Time (40 hours per week)
# 9            Full-Time (40 hours per week)
# 10           Full-Time (40 hours per week)
# 11           Full-Time (40 hours per week)
# 12                                     NaN
# 13           Full-Time (40 hours per week)
# 14           Full-Time (40 hours per week)
# 15                  Part-time, 50% or more
# 16           Full-Time (40 hours per week)
# 17           Full-Time (40 hours per week)
# 18           Full-Time (40 hours per week)
# 19                               Freelance
#
#     CShr1other. If you selected ‘other’, please specify:  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#     CShr2. How many days per month do you work on surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1                                                4.00
# 2                                                 NaN
# 3                                                 NaN
# 4                                                1.00
# 5                                                4.00
# 6                                                0.00
# 7                                                3.00
# 8                                                2.00
# 9                                                1.00
# 10                                               0.25
# 11                                               2.00
# 12                                                NaN
# 13                                                NaN
# 14                                               2.00
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                               2.00
# 19                                               5.00
#
#    CSexpertise1. How many years have you spent working on surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1                                                  20
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   9
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  12
# 8                                                  12
# 9                                                  10
# 10                                                NaN
# 11                                                  5
# 12                                                NaN
# 13                                                NaN
# 14                                                 <1
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                  5
# 19                                                 20
#
#    CSexpertise2. How do you assess your level of expertise concerning the legal aspects of surveillance by intelligence agencies?  \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Advanced knowledge (I only require external ad...
# 5   Advanced knowledge (I only require external ad...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Expert knowledge (I rarely require external ad...
# 9   Advanced knowledge (I only require external ad...
# 10                                                NaN
# 11  Advanced knowledge (I only require external ad...
# 12                                                NaN
# 13                                                NaN
# 14  Basic knowledge (I require external advice in ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Some knowledge (I require external advice from...
# 19  Some knowledge (I require external advice from...
#
#    CSexpertise3. How do you assess your level of expertise concerning the political aspects of surveillance by intelligence agencies?   \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Some knowledge (I require external advice from...
# 5   Advanced knowledge (I only require external ad...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Advanced knowledge (I only require external ad...
# 9   Advanced knowledge (I only require external ad...
# 10                                                NaN
# 11  Some knowledge (I require external advice from...
# 12                                                NaN
# 13                                                NaN
# 14  Some knowledge (I require external advice from...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Advanced knowledge (I only require external ad...
# 19  Some knowledge (I require external advice from...
#
#    CSexpertise4. How do you assess your level of expertise concerning the technical aspects of surveillance by intelligence agencies?   \
# 0                                                 NaN
# 1   Some knowledge (I require external advice from...
# 2                                                 NaN
# 3                                                 NaN
# 4   Some knowledge (I require external advice from...
# 5   Some knowledge (I require external advice from...
# 6   Advanced knowledge (I only require external ad...
# 7   Advanced knowledge (I only require external ad...
# 8   Some knowledge (I require external advice from...
# 9   Some knowledge (I require external advice from...
# 10                                                NaN
# 11  Some knowledge (I require external advice from...
# 12                                                NaN
# 13                                                NaN
# 14    No knowledge (I always require external advice)
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Some knowledge (I require external advice from...
# 19  Some knowledge (I require external advice from...
#
#    CSfinance1. How do you assess the financial resources that have been available for your work on intelligence over the past 5 years?  \
# 0                                                 NaN
# 1   There was very little funding (It is exception...
# 2                                                 NaN
# 3                                                 NaN
# 4   There was sufficient funding (We have in most ...
# 5   There was very little funding (It is exception...
# 6   There was very little funding (It is exception...
# 7   There was very little funding (It is exception...
# 8                                                 NaN
# 9   There was sufficient funding (We have in most ...
# 10                                                NaN
# 11  There was very little funding (It is exception...
# 12                                                NaN
# 13                                                NaN
# 14  There was some funding (From time to time our ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  There was some funding (From time to time our ...
# 19  There was some funding (From time to time our ...
#
#    CSfinance2[SQ01]. How important are the following funding categories for your organisation's work on intelligence-related issues? [Private foundations]  \
# 0                                                 NaN
# 1                                           Important
# 2                                                 NaN
# 3                                                 NaN
# 4                                           Important
# 5                                           Important
# 6                                      Very important
# 7                                      Very important
# 8                                                 NaN
# 9                                      Very important
# 10                                                NaN
# 11                                     Very important
# 12                                                NaN
# 13                                                NaN
# 14                                 Slightly important
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                          Important
# ...
# 17                                                NaN
# 18                                                NaN
# 19                                      Chatham House
#
#    CSsnowball[SQ03]. Thank you very much for your participation. It means a lot to us. Thanks to you and other voluntary participants we can advance the knowledge base on intelligence oversight and democratic control of surveillance in the digital age. If you like, please name up to three other experts or organisations that work on intelligence-related issues that you think could fill out this survey in order to provide us with an even better picture of civic intelligence oversight. (Please do not include contact information.) [Person or organisation 3]  \
# 0                                                 NaN
# 1                               Hermes Centre (Italy)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                   Open Rights Group
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                              Sir Bernard Silverman
#
#    CSEmail. If you want to hear about the results of this survey, please enter your email address here:
# 0                                                 NaN
# 1                                yasha@statewatch.org
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                  douwe@korff.co.uk
# 6                           javier@ruizmacpherson.org
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                     gph@herdale.uk
